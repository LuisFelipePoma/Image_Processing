# %% [markdown]
# ## **Universidad Peruana de Ciencias Aplicadas**
# ### CC235 - Procesamiento de Imágenes
# ### Segmentación de imágenes
#
# ---
#
# ### Segmentación Watershed

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage.segmentation import watershed
from skimage.feature import peak_local_max

# %% [markdown]
# ### Crearemos la imagen de prueba
#
# Imaginemos que son dos monedas de distinta denominación con oclusión

# %%
x, y = np.indices((80, 80))
x1, y1, x2, y2 = 28, 28, 44, 52
r1, r2 = 16, 20
mask_moneda1 = (x - x1)**2 + (y - y1)**2 < r1**2
mask_moneda2 = (x - x2)**2 + (y - y2)**2 < r2**2
image = np.logical_or(mask_moneda1, mask_moneda2)
plt.imshow(image, cmap='gray')

# %% [markdown]
# Vamos a usar [ndimage.distance_transform_edt](https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.distance_transform_edt.html) que nos permite calcular la distancia de de cada punto (de la región con 1's) al punto más cercano del fondo (de la región con 0's)

# %%
distance = ndimage.distance_transform_edt(image)
plt.imshow(distance, cmap='gray')

# %% [markdown]
# Vamos a usar la función [skimage.feature.peak_local_max](https://scikit-image.org/docs/0.12.x/api/skimage.feature.html#skimage.feature.peak_local_max) para encontrar los 'picos' en la imagen. Esto nos servirá para tener una suerte de 'semillas'

# %%
local_maxi = peak_local_max(image=distance, indices=False, footprint=np.ones((3, 3)),labels=image)
plt.imshow(local_maxi, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Codes\image-processing\src\7_Segmentacion\Segmentación de imágenes.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Codes/image-processing/src/7_Segmentacion/Segmentaci%C3%B3n%20de%20im%C3%A1genes.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> local_maxi = peak_local_max(image=distance, indices=False, footprint=np.ones((3, 3)),labels=image)
#       <a href='vscode-notebook-cell:/d%3A/Codes/image-processing/src/7_Segmentacion/Segmentaci%C3%B3n%20de%20im%C3%A1genes.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.imshow(local_maxi, cmap='gray')
#
# TypeError: peak_local_max() got an unexpected keyword argument 'indices'

# %% [markdown]
# A continuación vamos a usar la función [skimage.segmentation.watershed ](https://scikit-image.org/docs/dev/api/skimage.segmentation.html#skimage.segmentation.watershed)

# %%
markers = ndimage.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=image)
plt.imshow(labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Codes\image-processing\src\7_Segmentacion\Segmentación de imágenes.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/d%3A/Codes/image-processing/src/7_Segmentacion/Segmentaci%C3%B3n%20de%20im%C3%A1genes.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> markers = ndimage.label(local_maxi)[0]
# ----> <a href='vscode-notebook-cell:/d%3A/Codes/image-processing/src/7_Segmentacion/Segmentaci%C3%B3n%20de%20im%C3%A1genes.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> labels = watershed(-distance, markers, mask=image)
#       <a href='vscode-notebook-cell:/d%3A/Codes/image-processing/src/7_Segmentacion/Segmentaci%C3%B3n%20de%20im%C3%A1genes.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(labels)
#
# File d:\Codes\image-processing\.env\Lib\site-packages\skimage\segmentation\_watershed.py:199, in watershed(image, markers, connectivity, offset, mask, compactness, watershed_line)
#      86 def watershed(image, markers=None, connectivity=1, offset=None, mask=None,
#      87               compactness=0, watershed_line=False):
#      88     """Find watershed basins in `image` flooded from given `markers`.
#      89
#      90     Parameters
#    (...)
#     197     separate overlapping spheres.
#     198     """
# --> 199     image, markers, mask = _validate_inputs(image, markers, mask, connectivity)
#     200     connectivity, offset = _validate_connectivity(image.ndim, connectivity,
#     201                                                   offset)
#     203     # pad the image, markers, and mask so that we can use the mask to
#     204     # keep from running off the edges
#
# File d:\Codes\image-processing\.env\Lib\site-packages\skimage\segmentation\_watershed.py:76, in _validate_inputs(image, markers, mask, connectivity)
#      74     markers *= mask
#      75 else:
# ---> 76     markers = np.asanyarray(markers) * mask
#      77     if markers.shape != image.shape:
#      78         message = (f'`markers` (shape {markers.shape}) must have same '
#      79                    f'shape as `image` (shape {image.shape})')
#
# ValueError: operands could not be broadcast together with shapes (2,2) (80,80)
