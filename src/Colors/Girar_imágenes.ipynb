# %%
# recordar:
texto = 'Procesamiento de imágenes'

# %%
texto[::-1]
# Out:
# 'senegámi ed otneimasecorP'

# %%
# !wget https://dam.smashmexico.com.mx/wp-content/uploads/2019/07/meme-spiderman.jpg -O image.jpg
# Out:
# --2023-08-23 07:45:34--  https://dam.smashmexico.com.mx/wp-content/uploads/2019/07/meme-spiderman.jpg
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving dam.smashmexico.com.mx (dam.smashmexico.com.mx)...
# 18.66.255.98, 18.66.255.48, 18.66.255.129, ...
# Connecting to dam.smashmexico.com.mx (dam.smashmexico.com.mx)|18.66.255.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66274 (65K) [image/jpeg]
# Saving to: ‘image.jpg’
#
# image.jpg           100%[===================>]  64.72K  --.-KB/s    in 0.08s
#
# 2023-08-23 07:45:35 (821 KB/s) - ‘image.jpg’ saved [66274/66274]

# %%
import matplotlib.pyplot as plt

im=plt.imread('image.jpg')
plt.imshow(im)

# %%
#slicing vertical
plt.imshow(im[:,550:,:])

# %%
plt.imshow(im[:150,:220,:])

# %%
# guardar un slicing:
im_spiderman_recortado = im[:,550:,:]

# %%
plt.imshow(im_spiderman_recortado)

# %%
plt.imshow(im_spiderman_recortado[:,::-1,:])
im_spiderman_recortado2 = im_spiderman_recortado[:,::-1,:]

# %%
import numpy as np

# %%
img_double = np.column_stack((im_spiderman_recortado2,im_spiderman_recortado))
plt.imshow(img_double)

# %%
imagen_final = im.copy()
imagen_final[:,:350,:] = im_spiderman_recortado[:,::-1,:]

# %%
plt.imshow(imagen_final)
